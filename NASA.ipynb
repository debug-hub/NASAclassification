# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("D:/neo_v2.csv")

# %%
df.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  9.083600e+04      90836.000000      90836.000000       90836.000000
# mean   1.438288e+07          0.127432          0.284947       48066.918918
# std    2.087202e+07          0.298511          0.667491       25293.296961
# min    2.000433e+06          0.000609          0.001362         203.346433
# 25%    3.448110e+06          0.019256          0.043057       28619.020645
# 50%    3.748362e+06          0.048368          0.108153       44190.117890
# 75%    3.884023e+06          0.143402          0.320656       62923.604633
# max    5.427591e+07         37.892650         84.730541      236990.128088
#
#        miss_distance  absolute_magnitude
# count   9.083600e+04        90836.000000
# mean    3.706655e+07           23.527103
# std     2.235204e+07            2.894086
# min     6.745533e+03            9.230000
# 25%     1.721082e+07           21.340000
# 50%     3.784658e+07           23.700000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  90836 non-null  int64
#  1   name                90836 non-null  object
#  2   est_diameter_min    90836 non-null  float64
#  3   est_diameter_max    90836 non-null  float64
#  4   relative_velocity   90836 non-null  float64
#  5   miss_distance       90836 non-null  float64
#  6   absolute_magnitude  90836 non-null  float64
#  7   hazardous           90836 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(1)
# memory usage: 4.9+ MB

# %%
df.head(10)
# Out:
#          id                 name  est_diameter_min  est_diameter_max  \
# 0   2162635  162635 (2000 SS164)          1.198271          2.679415
# 1   2277475    277475 (2005 WK4)          0.265800          0.594347
# 2   2512244   512244 (2015 YE18)          0.722030          1.614507
# 3   3596030          (2012 BV13)          0.096506          0.215794
# 4   3667127          (2014 GE35)          0.255009          0.570217
# 5  54138696          (2021 GY23)          0.036354          0.081291
# 6  54189957          (2021 PY40)          0.171615          0.383743
# 7  54230078           (2021 XD6)          0.005328          0.011914
# 8   2088213     88213 (2001 AF2)          0.350393          0.783502
# 9   3766065            (2016 YM)          0.105817          0.236614
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# ...

# %%
newdf=df.drop(['name'], axis = 1)

# %%
newdf
# Out:
#              id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0       2162635          1.198271          2.679415       13569.249224
# 1       2277475          0.265800          0.594347       73588.726663
# 2       2512244          0.722030          1.614507      114258.692129
# 3       3596030          0.096506          0.215794       24764.303138
# 4       3667127          0.255009          0.570217       42737.733765
# ...         ...               ...               ...                ...
# 90831   3763337          0.026580          0.059435       52078.886692
# 90832   3837603          0.016771          0.037501       46114.605073
# 90833  54017201          0.031956          0.071456        7566.807732
# 90834  54115824          0.007321          0.016370       69199.154484
# 90835  54205447          0.039862          0.089133       27024.455553
#
#        miss_distance  absolute_magnitude  hazardous
# 0       5.483974e+07               16.73      False
# ...

# %%
df.isna().sum()
# Out:
# id                    0
# name                  0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
df.hazardous.value_counts().plot(kind='bar')
plt.title('hazardous')
plt.show()

# %%
df.corr()
# Out:
#                           id  est_diameter_min  est_diameter_max  \
# id                  1.000000         -0.148322         -0.148322
# est_diameter_min   -0.148322          1.000000          1.000000
# est_diameter_max   -0.148322          1.000000          1.000000
# relative_velocity  -0.059176          0.221553          0.221553
# miss_distance      -0.056510          0.142241          0.142241
# absolute_magnitude  0.277258         -0.560188         -0.560188
# hazardous          -0.123443          0.183363          0.183363
#
#                     relative_velocity  miss_distance  absolute_magnitude  \
# id                          -0.059176      -0.056510            0.277258
# est_diameter_min             0.221553       0.142241           -0.560188
# est_diameter_max             0.221553       0.142241           -0.560188
# relative_velocity            1.000000       0.327169           -0.353863
# miss_distance                0.327169       1.000000           -0.264168
# ...

# %%
features_num = ['est_diameter_min', 'est_diameter_max',
                'relative_velocity', 'miss_distance',
                'absolute_magnitude']

# %%
df[features_num].describe()
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# count      90836.000000      90836.000000       90836.000000   9.083600e+04
# mean           0.127432          0.284947       48066.918918   3.706655e+07
# std            0.298511          0.667491       25293.296961   2.235204e+07
# min            0.000609          0.001362         203.346433   6.745533e+03
# 25%            0.019256          0.043057       28619.020645   1.721082e+07
# 50%            0.048368          0.108153       44190.117890   3.784658e+07
# 75%            0.143402          0.320656       62923.604633   5.654900e+07
# max           37.892650         84.730541      236990.128088   7.479865e+07
#
#        absolute_magnitude
# count        90836.000000
# mean            23.527103
# std              2.894086
# min              9.230000
# 25%             21.340000
# 50%             23.700000
# 75%             25.700000
# max             33.200000

# %%
sns.pairplot(data=df[features_num],
             plot_kws = {'alpha': 0.2, 's': 2})
plt.show()

## we use the alpha argument to control the transparency of plots.
##

# %%
sns.pairplot(data=df[features_num + ['hazardous']],
             hue='hazardous',
             plot_kws = {'alpha': 0.2, 's': 1})
plt.show()

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20, 10))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="PiYG")

# %%
corr_pearson = df[features_num].corr(method='pearson')
corr_spearman = df[features_num].corr(method='spearman')

plt.figure(figsize=(18,6))
ax1 = plt.subplot(1,2,1)
sns.heatmap(corr_pearson, annot=True, cmap='YlGnBu', vmin=-1, vmax=+1)
plt.title('Pearson Correlation')

ax2 = plt.subplot(1,2,2, sharex=ax1)
sns.heatmap(corr_spearman, annot=True, cmap='BuPu', vmin=-1, vmax=+1)
plt.title('Spearman Correlation')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df.est_diameter_min, vert=False)
plt.title('est_diameter_min')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df.est_diameter_max, vert=False)
plt.title('est_diameter_max')
plt.show()

# %%
for f in features_num:
    plt.figure(figsize=(10,4))
    sns.violinplot(data=df, x=f, y='hazardous', orient='h')
    my_title = f + ' by hazardous'
    plt.title(my_title)
    plt.grid()

# %%
newdf
# Out:
#              id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0       2162635          1.198271          2.679415       13569.249224
# 1       2277475          0.265800          0.594347       73588.726663
# 2       2512244          0.722030          1.614507      114258.692129
# 3       3596030          0.096506          0.215794       24764.303138
# 4       3667127          0.255009          0.570217       42737.733765
# ...         ...               ...               ...                ...
# 90831   3763337          0.026580          0.059435       52078.886692
# 90832   3837603          0.016771          0.037501       46114.605073
# 90833  54017201          0.031956          0.071456        7566.807732
# 90834  54115824          0.007321          0.016370       69199.154484
# 90835  54205447          0.039862          0.089133       27024.455553
#
#        miss_distance  absolute_magnitude  hazardous
# 0       5.483974e+07               16.73      False
# ...

# %%
x=newdf.iloc[:,:-1]
y=newdf.iloc[:,-1]

# %%
x
# Out:
#              id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0       2162635          1.198271          2.679415       13569.249224
# 1       2277475          0.265800          0.594347       73588.726663
# 2       2512244          0.722030          1.614507      114258.692129
# 3       3596030          0.096506          0.215794       24764.303138
# 4       3667127          0.255009          0.570217       42737.733765
# ...         ...               ...               ...                ...
# 90831   3763337          0.026580          0.059435       52078.886692
# 90832   3837603          0.016771          0.037501       46114.605073
# 90833  54017201          0.031956          0.071456        7566.807732
# 90834  54115824          0.007321          0.016370       69199.154484
# 90835  54205447          0.039862          0.089133       27024.455553
#
#        miss_distance  absolute_magnitude
# 0       5.483974e+07               16.73
# ...

# %%
y
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 90831    False
# 90832    False
# 90833    False
# 90834    False
# 90835    False
# Name: hazardous, Length: 90836, dtype: bool

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25)

# %%
print(x_test.shape)
print(y_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (22709, 6)
# (22709,)
# (68127, 6)
# (68127,)

# %%
## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
dt = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)

# %%
x_train
# Out:
#              id  est_diameter_min  est_diameter_max  relative_velocity  \
# 87454  54262973          0.014209          0.031772       32651.536461
# 31933   2275975          0.339277          0.758647       48828.201118
# 1042    3618296          0.044112          0.098637       59338.673750
# 54848   3831851          0.003346          0.007482       55022.102223
# 23557   3370021          0.096506          0.215794       65226.040240
# ...         ...               ...               ...                ...
# 67477   3719151          0.139494          0.311918       60350.369352
# 20895   2539063          0.402305          0.899580       55063.867412
# 27326   3843826          0.004411          0.009864       15033.798250
# 65245  54212438          0.003669          0.008204       55363.548476
# 26862   2011500          0.576176          1.288368       41184.250302
#
#        miss_distance  absolute_magnitude
# 87454   4.171098e+07               26.36
# ...

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %%
dt.score(x_train,y_train)
# Out:
# 0.9158336635988669

# %%
dt.score(x_test,y_test)
# Out:
# 0.9129420053723194

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[20361    93]
#  [ 1884   371]]

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.92      0.95     22245
#         True       0.16      0.80      0.27       464
#
#     accuracy                           0.91     22709
#    macro avg       0.58      0.86      0.61     22709
# weighted avg       0.98      0.91      0.94     22709

# %%
### CLASSIFICATION BY RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFc=RandomForestClassifier(n_estimators=15)
RFc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=15)

# %%
print('Training Score :', RFc.score(x_train,y_train))
print('Testing Score :', RFc.score(x_test,y_test))
# Out:
# Training Score : 0.9989578287609905
# Testing Score : 0.9478180457087498

# %%
RF_x_pred=RFc.predict(x_test)

# %%
RF_x_pred
# Out:
# array([ True, False, False, ..., False, False,  True])

# %%
print(classification_report(RF_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97     20967
#         True       0.62      0.81      0.70      1742
#
#     accuracy                           0.95     22709
#    macro avg       0.80      0.88      0.84     22709
# weighted avg       0.96      0.95      0.95     22709

# %%
print(confusion_matrix(y_test,RF_pred))
# Out:
# [[20118   336]
#  [  849  1406]]
